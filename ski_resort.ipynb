# %%
import requests
import os
from dotenv import load_dotenv

# Load API key from .env file
load_dotenv()
API_KEY = "AIzaSyByNf59K-tl5Xkb3UIZv5XkNNC2Wfln5Kc"


def get_ski_resorts(lat, lng, radius=50000):
    url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    params = {
        "location": f"{lat},{lng}",
        "radius": radius,  # Search radius in meters
        "type": "ski_resort",
        "key": API_KEY
    }
    
    response = requests.get(url, params=params)
    data = response.json()

    if "results" in data:
        resorts = []
        for place in data["results"]:
            if 'ski' in place.get('name', '').lower():  # Filter based on name containing "ski"
                resorts.append({
                    "name": place.get("name"),
                    "address": place.get("vicinity"),
                    "rating": place.get("rating", "N/A"),
                    "lat": place["geometry"]["location"]["lat"],
                    "lng": place["geometry"]["location"]["lng"]
                })
        return resorts
    else:
        print("Error:", data.get("error_message", "Unknown error"))
        return []

# Example: Search near Denver, Colorado
latitude = 42.340382
longitude = -72.496819
ski_resorts = get_ski_resorts(latitude, longitude)

# Print results
for i, resort in enumerate(ski_resorts, 1):
    print(f"{i}. {resort['name']} ({resort['rating']}⭐)")
    print(f"   Address: {resort['address']}")
    print(f"   Location: {resort['lat']}, {resort['lng']}\n")

# %%
import requests
from dotenv import load_dotenv

# Load API key from .env file
load_dotenv()
API_KEY = "AIzaSyByNf59K-tl5Xkb3UIZv5XkNNC2Wfln5Kc"

# Function to get latitude and longitude from a ZIP code
def get_lat_lng_from_zip(zip_code):
    geocode_url = f"https://maps.googleapis.com/maps/api/geocode/json"
    
    params = {
        "address": zip_code,  # ZIP code as address
        "key": API_KEY
    }
    
    response = requests.get(geocode_url, params=params)
    data = response.json()
    
    if "results" in data and data["results"]:
        # Extract latitude and longitude from the first result
        lat = data["results"][0]["geometry"]["location"]["lat"]
        lng = data["results"][0]["geometry"]["location"]["lng"]
        return lat, lng
    else:
        print("Error: Unable to get location for ZIP code.")
        return None, None

# Function to get ski resorts near a specific location (lat, lng)
def get_ski_resorts(lat, lng, radius=200000):
    url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    params = {
        "location": f"{lat},{lng}",
        "radius": radius,  # Search radius in meters
        "keyword": "ski resort",  # Broad search for related terms
        "key": API_KEY
    }
    
    response = requests.get(url, params=params)
    data = response.json()

    if "results" in data:
        resorts = []
        for place in data["results"]:
            # Filter based on types related to resorts
            if "point_of_interest" in place.get("types", []) or "tourist_attraction" in place.get("types", []):
                resorts.append({
                    "name": place.get("name"),
                    "address": place.get("vicinity"),
                    "rating": place.get("rating", "N/A"),
                    "lat": place["geometry"]["location"]["lat"],
                    "lng": place["geometry"]["location"]["lng"]
                })
        return resorts
    else:
        print("Error:", data.get("error_message", "Unknown error"))
        return []

# Example: Search for ski resorts near a ZIP code
zip_code = "01003"  
latitude, longitude = get_lat_lng_from_zip(zip_code)

if latitude and longitude:
    ski_resorts = get_ski_resorts(latitude, longitude)

    # Print results
    for i, resort in enumerate(ski_resorts, 1):
        print(f"{i}. {resort['name']} ({resort['rating']}⭐)")
        print(f"   Address: {resort['address']}")
        print(f"   Location: {resort['lat']}, {resort['lng']}\n")
# Out:
# 1. Berkshire East Mountain Resort (4.8⭐)
#    Address: 66 Thunder Mountain Rd, Charlemont
#    Location: 42.6211485, -72.87713500000001
#
# 2. Otis Ridge (4.7⭐)
#    Address: 159 Monterey Rd, Otis
#    Location: 42.19638399999999, -73.0983352
#
# 3. Northfield Mountain Ski Center (4.6⭐)
#    Address: 99 Millers Falls Rd, Northfield
#    Location: 42.610827, -72.471313
#
# 4. Stump Sprouts Ski Touring Center (4.9⭐)
#    Address: 64 W Hill Rd, Hawley
#    Location: 42.5866087, -72.9515617
#
# 5. Canterbury Farm (4.9⭐)
#    Address: 1986 Fred Snow Rd, Becket
#    Location: 42.3095973, -73.0943423

# %%
import requests
from dotenv import load_dotenv

# Load API key from .env file
load_dotenv()
API_KEY = "AIzaSyByNf59K-tl5Xkb3UIZv5XkNNC2Wfln5Kc"

# Function to get latitude and longitude from a ZIP code
def get_lat_lng_from_zip(zip_code):
    geocode_url = f"https://maps.googleapis.com/maps/api/geocode/json"
    
    params = {
        "address": zip_code,  # ZIP code as address
        "key": API_KEY
    }
    
    response = requests.get(geocode_url, params=params)
    data = response.json()
    
    if "results" in data and data["results"]:
        # Extract latitude and longitude from the first result
        lat = data["results"][0]["geometry"]["location"]["lat"]
        lng = data["results"][0]["geometry"]["location"]["lng"]
        return lat, lng
    else:
        print("Error: Unable to get location for ZIP code.")
        return None, None

# Function to get ski resorts near a specific location (lat, lng)
def get_ski_resorts(lat, lng, radius=165000):
    url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    # Focused search with specific terms and types
    params = {
        "location": f"{lat},{lng}",
        "radius": radius,  # Search radius in meters
        "type": "establishment",  # Use more general term to include a broader range
        "keyword": "ski resort",  # Try searching with the more specific term
        "rankby": "distance", 
        "key": API_KEY
    }
    
    response = requests.get(url, params=params)
    data = response.json()

    if "results" in data:
        resorts = []
        for place in data["results"]:
            # Filter based on specific types or other relevant criteria
            if "point_of_interest" in place.get("types", []) or "tourist_attraction" in place.get("types", []):
                resorts.append({
                    "name": place.get("name"),
                    "address": place.get("vicinity"),
                    "rating": place.get("rating", "N/A"),
                    "lat": place["geometry"]["location"]["lat"],
                    "lng": place["geometry"]["location"]["lng"]
                })
        return resorts
    else:
        print("Error:", data.get("error_message", "Unknown error"))
        return []

# Example: Search for ski resorts near Amherst, MA (ZIP code 01002)
zip_code = "01002"  # Amherst, MA ZIP code
latitude, longitude = get_lat_lng_from_zip(zip_code)

if latitude and longitude:
    # Try to fetch results with a reasonable radius
    ski_resorts = get_ski_resorts(latitude, longitude, radius=60000)  # Adjust radius slightly if necessary

    # Print results
    for i, resort in enumerate(ski_resorts, 1):
        print(f"{i}. {resort['name']} ({resort['rating']}⭐)")
        #print(f"   Address: {resort['address']}")
        #print(f"   Location: {resort['lat']}, {resort['lng']}\n")
else:
    print("Failed to retrieve location coordinates.")

# %%
import requests
from dotenv import load_dotenv
import os
import time  # Needed for handling pagination delay
import spacy
import re

# Load API key from .env file
load_dotenv()
API_KEY = "AIzaSyAPXZKd6RPQCrFAxZB3HKBTz_CeW2624sc"

# Function to get latitude and longitude from a location name
def get_lat_lng_from_location(location):
    geocode_url = "https://maps.googleapis.com/maps/api/geocode/json"
    
    params = {
        "address": location,  
        "key": API_KEY
    }
    
    response = requests.get(geocode_url, params=params)
    data = response.json()
    
    if "results" in data and data["results"]:
        lat = data["results"][0]["geometry"]["location"]["lat"]
        lng = data["results"][0]["geometry"]["location"]["lng"]
        return lat, lng
    else:
        print("Error: Unable to get location for", location)
        return None, None

# Function to get ski resorts near a location (lat, lng) with pagination
def get_ski_resorts(lat, lng, radius=200000):
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    all_resorts = []
    next_page_token = None

    while True:
        params = {
            "location": f"{lat},{lng}",
            "radius": radius,
            "keyword": "ski resort",  
            "key": API_KEY
        }
        if next_page_token:
            params["pagetoken"] = next_page_token  # Fetch next page

        response = requests.get(url, params=params)
        data = response.json()

        if "results" in data:
            for place in data["results"]:
                all_resorts.append({
                    "name": place.get("name"),
                    "address": place.get("vicinity"),
                    "rating": place.get("rating", "N/A"),
                    "lat": place["geometry"]["location"]["lat"],
                    "lng": place["geometry"]["location"]["lng"]
                })

        next_page_token = data.get("next_page_token")
        if not next_page_token:
            break  # No more results, exit loop

        time.sleep(2)  # Required delay before next page request

    return all_resorts

# Example: Search for ski resorts near Colorado
user_query = "Best ski resorts for snowboarding in Amherst"
location = "Amherst"  # We'll later automate this extraction
latitude, longitude = get_lat_lng_from_location(location)

if latitude and longitude:
    ski_resorts = get_ski_resorts(latitude, longitude)

    # Print results
    for i, resort in enumerate(ski_resorts, 1):
        print(f"{i}. {resort['name']} ({resort['rating']}⭐)")
else:
    print("Failed to retrieve location coordinates.")

# %%
import requests
from dotenv import load_dotenv
import os
import time
import spacy  # For location extraction

# Load API key from .env file
load_dotenv()
API_KEY = "AIzaSyAPXZKd6RPQCrFAxZB3HKBTz_CeW2624sc"

# Load spaCy model for location extraction
nlp = spacy.load("en_core_web_sm")

# Function to get latitude and longitude from a location name
def get_lat_lng_from_location(location):
    geocode_url = "https://maps.googleapis.com/maps/api/geocode/json"
    
    params = {
        "address": location,
        "key": API_KEY
    }
    
    response = requests.get(geocode_url, params=params)
    data = response.json()
    
    if "results" in data and data["results"]:
        lat = data["results"][0]["geometry"]["location"]["lat"]
        lng = data["results"][0]["geometry"]["location"]["lng"]
        return lat, lng
    else:
        print("Error: Unable to get location for", location)
        return None, None

# Function to extract location and activity keywords from the user query
def extract_keywords(query):
    doc = nlp(query)
    
    # Extract location
    location = None
    for ent in doc.ents:
        if ent.label_ == "GPE":  # Geopolitical Entity (cities, countries)
            location = ent.text
    
    # Extract activities
    activities = ["snowboarding", "skiing", "ski", "boarding", "ski resorts"]
    keywords = [activity for activity in activities if activity in query.lower()]
    
    return location, keywords

# Function to get ski resorts near a location (lat, lng) with pagination
def get_ski_resorts(lat, lng, radius=200000):
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    all_resorts = []
    next_page_token = None

    while True:
        params = {
            "location": f"{lat},{lng}",
            "radius": radius,
            "keyword": "ski resort",  
            "key": API_KEY
        }
        if next_page_token:
            params["pagetoken"] = next_page_token

        response = requests.get(url, params=params)
        data = response.json()

        if "results" in data:
            for place in data["results"]:
                all_resorts.append({
                    "name": place.get("name"),
                    "address": place.get("vicinity"),
                    "rating": place.get("rating", "N/A"),
                    "lat": place["geometry"]["location"]["lat"],
                    "lng": place["geometry"]["location"]["lng"]
                })

        next_page_token = data.get("next_page_token")
        if not next_page_token:
            break

        time.sleep(2)  # Required delay before next page request

    return all_resorts

# Main execution
user_query = "Best ski resorts for snowboarding in Amherst"  # Example input

# Step 1: Extract location and activities
location, activities = extract_keywords(user_query)

if location:
    # Step 2: Get latitude and longitude for the location
    latitude, longitude = get_lat_lng_from_location(location)

    if latitude and longitude:
        # Step 3: Find ski resorts near the location
        ski_resorts = get_ski_resorts(latitude, longitude)

        # Step 4: Rank results using embeddings (add your ranking logic here)

        # Example output
        for i, resort in enumerate(ski_resorts, 1):
            print(f"{i}. {resort['name']} ({resort['rating']}⭐)")
    else:
        print("Failed to retrieve location coordinates.")
else:
    print("Failed to extract location from query.")
# Out:
# Failed to extract location from query.

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      |████████████████████████████████| 12.8 MB 993 kB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.1.1; however, version 25.0.1 is available.
# You should consider upgrading via the '/Users/saimnaushad/.pyenv/versions/3.8.10/bin/python -m pip install --upgrade pip' command.
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
pip install sentence-transformers
# Out:
# ...
#      |████████████████████████████████| 255 kB 1.4 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.1.1; however, version 25.0.1 is available.
# You should consider upgrading via the '/Users/saimnaushad/.pyenv/versions/3.8.10/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from dotenv import load_dotenv
import os
import time
import spacy 
from sentence_transformers import SentenceTransformer
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Load environment variables
load_dotenv()
API_KEY = "AIzaSyA6N-afJlUegG7uhVeUyAlusbLK912IH70" 

# Load the pre-trained sentence transformer model
model = SentenceTransformer('paraphrase-distilroberta-base-v1')
nlp = spacy.load("en_core_web_trf")  

# Function to get latitude and longitude from a location (using Google Geocoding API)
def get_lat_lng_from_location(location):
    geocode_url = "https://maps.googleapis.com/maps/api/geocode/json"
    params = {
        "address": location,
        "key": API_KEY
    }
    
    response = requests.get(geocode_url, params=params)
    data = response.json()
    
    if "results" in data and data["results"]:
        lat = data["results"][0]["geometry"]["location"]["lat"]
        lng = data["results"][0]["geometry"]["location"]["lng"]
        return lat, lng
    return None, None

# Function to get nearby ski resorts from Google Places API
def get_ski_resorts(lat, lng, radius=200000):
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    all_resorts = []
    next_page_token = None

    keywords = ["ski resort", "snowboarding", "ski area", "mountain resort", "winter sports", "snow sports", "ski mountain"]

    while True:
        for keyword in keywords:
            params = {
                "location": f"{lat},{lng}",
                "radius": radius,
                "keyword": keyword,
                "key": API_KEY,
                "components": "country:US"  # Restrict results to the U.S.
            }

            if next_page_token:
                params["pagetoken"] = next_page_token  

            response = requests.get(url, params=params)
            data = response.json()
            
            if data.get("status") != "OK":
                print(f"API Error: {data.get('status')}")
                continue

            if "results" in data:
                print(f"Found {len(data['results'])} results for keyword: {keyword}")
                for place in data["results"]:
                    resort = {
                        "name": place.get("name"),
                        "address": place.get("vicinity"),
                        "rating": place.get("rating", "N/A"),
                        "lat": place["geometry"]["location"]["lat"],
                        "lng": place["geometry"]["location"]["lng"]
                    }
                    # Filter results that are outside the US based on address
                    if is_us_based(resort['address']):
                        all_resorts.append(resort)
            
            next_page_token = data.get("next_page_token")
            
            if not next_page_token:
                break  # Exit inner loop if no more pages are available

        if not next_page_token:
            break  # Exit outer loop if no more pages are available

        time.sleep(2)  # Pause to avoid exceeding rate limits

    print(f"Total resorts fetched: {len(all_resorts)}")
    return all_resorts

# Function to extract location from user query using spaCy
def extract_location(query):
    doc = nlp(query)
    for ent in doc.ents:
        if ent.label_ in ["GPE", "LOC"]: 
            return ent.text
    return None  

# Function to create embeddings for resorts
def create_resort_embeddings(resorts):
    embeddings = []
    for resort in resorts:
        text = resort['name'] + " " + resort['address']
        embedding = model.encode(text)  
        embeddings.append(embedding)
    print(f"Generated {len(embeddings)} resort embeddings")
    return np.array(embeddings)

# Function to get top N matching resorts based on a user query
def get_top_matches(query, resort_embeddings, resorts, top_n=5):
    user_query_embedding = model.encode(query)
    user_query_embedding = user_query_embedding.reshape(1, -1)

    if len(resort_embeddings.shape) == 1:
        resort_embeddings = resort_embeddings.reshape(1, -1)

    # Calculate cosine similarities
    similarities = cosine_similarity(user_query_embedding, resort_embeddings)
    sorted_indices = np.argsort(similarities[0])[::-1][:top_n]
    
    # Return the top N matching resorts
    top_resorts = [resorts[i] for i in sorted_indices]
    print(f"Top matching resorts: {top_resorts}")
    return top_resorts

# Main code execution
user_query = "Resorts near Amherst"
location = extract_location(user_query)

latitude, longitude = get_lat_lng_from_location(location)

if latitude and longitude:
    print(f"Location: {location} (Lat: {latitude}, Lng: {longitude})")
    ski_resorts = get_ski_resorts(latitude, longitude)
    
    # Check if any resorts were found
    if not ski_resorts:
        print("No ski resorts found near the location.")
    else:
        resort_embeddings = create_resort_embeddings(ski_resorts)
        
        if resort_embeddings.shape[0] == 0:
            print("No valid resort embeddings generated.")
        else:
            top_resorts = get_top_matches(user_query, resort_embeddings, ski_resorts, top_n=10)
            
            if top_resorts:
                for resort in top_resorts:
                    print(f"{resort['name']}, Address: {resort['address']}")
            else:
                print("No matching resorts found.")
else:
    print("Failed to retrieve location coordinates.")
# Out:
# Location: Amherst (Lat: 42.3732216, Lng: -72.5198537)
# Found 5 results for keyword: ski resort
# Total resorts fetched: 0
# No ski resorts found near the location.

# %%
import requests
from dotenv import load_dotenv
import os
import time
import spacy 
from sentence_transformers import SentenceTransformer
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Load environment variables
load_dotenv()
API_KEY = "AIzaSyA6N-afJlUegG7uhVeUyAlusbLK912IH70"  

# Load the pre-trained sentence transformer model
model = SentenceTransformer('paraphrase-distilroberta-base-v1')
nlp = spacy.load("en_core_web_trf")  

# Function to get latitude and longitude from a location (using Google Geocoding API)
def get_lat_lng_from_location(location):
    geocode_url = "https://maps.googleapis.com/maps/api/geocode/json"
    params = {"address": location, "key": API_KEY}
    
    response = requests.get(geocode_url, params=params)
    data = response.json()
    
    if "results" in data and data["results"]:
        lat = data["results"][0]["geometry"]["location"]["lat"]
        lng = data["results"][0]["geometry"]["location"]["lng"]
        return lat, lng
    return None, None

# Function to check if the place is a valid ski resort
# Function to check if the place is a valid ski resort
def is_valid_ski_resort(place_id):
    details_url = "https://maps.googleapis.com/maps/api/place/details/json"
    params = {"place_id": place_id, "key": API_KEY, "fields": "name,types,editorial_summary"}

    response = requests.get(details_url, params=params)
    data = response.json()

    if "result" in data:
        name = data["result"].get("name", "").lower()
        summary = data["result"].get("editorial_summary", {}).get("overview", "").lower()
        types = data["result"].get("types", [])

        # Allowed types (Expanded)
        allowed_types = {"ski_resort", "tourist_attraction", "lodging", "park", "point_of_interest"}

        # Keywords indicating a valid ski resort (Expanded)
        valid_keywords = ["ski", "snowboard", "mountain", "resort", "alpine", "downhill"]

        # Debugging Output
        print(f"Checking {place_id} - Name: {name}, Types: {types}, Summary: {summary}")

        # New logic: If name or summary contains any valid keyword OR if it's in allowed types
        if any(t in allowed_types for t in types) and any(kw in name or kw in summary for kw in valid_keywords):
            return True

        print(f"❌ Rejected: {name} - Doesn't match criteria")
    return False

# Function to get nearby ski resorts from Google Places API
def get_ski_resorts(lat, lng, radius=200000):
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    all_resorts = []
    keywords = ["ski resort", "ski area", "ski mountain", "skiing", "snowboarding"]
    seen_resorts = set()  # To store unique resorts

    for keyword in keywords:
        next_page_token = None

        while True:
            params = {
                "location": f"{lat},{lng}",
                "radius": radius,
                "keyword": keyword,
                "key": API_KEY
            }
            if next_page_token:
                params["pagetoken"] = next_page_token  

            response = requests.get(url, params=params)
            data = response.json()

            if data.get("status") != "OK":
                print(f"API Error: {data.get('status')}")
                break

            if "results" in data:
                print(f"Found {len(data['results'])} results for keyword: {keyword}")

                for place in data["results"]:
                    place_id = place.get("place_id")
                    if place_id in seen_resorts:
                        continue  # Skip duplicates
                    
                    if is_valid_ski_resort(place_id):
                        resort = {
                            "name": place.get("name"),
                            "address": place.get("vicinity"),
                            "rating": place.get("rating", "N/A"),
                            "lat": place["geometry"]["location"]["lat"],
                            "lng": place["geometry"]["location"]["lng"]
                        }
                        all_resorts.append(resort)
                        seen_resorts.add(place_id)

            next_page_token = data.get("next_page_token")
            if not next_page_token:
                break  # Exit loop if no more pages

            time.sleep(2)  # Pause to avoid API rate limit

    print(f"Total valid ski resorts fetched: {len(all_resorts)}")
    return all_resorts

# Function to extract location from user query using spaCy
def extract_location(query):
    doc = nlp(query)
    for ent in doc.ents:
        if ent.label_ in ["GPE", "LOC"]: 
            return ent.text
    return None  

# Function to create embeddings for resorts
def create_resort_embeddings(resorts):
    embeddings = []
    for resort in resorts:
        text = resort['name'] + " " + resort['address']
        embedding = model.encode(text)  
        embeddings.append(embedding)
    print(f"Generated {len(embeddings)} resort embeddings")
    return np.array(embeddings)

# Function to get top N matching resorts based on a user query
def get_top_matches(query, resort_embeddings, resorts, top_n=5):
    user_query_embedding = model.encode(query)
    user_query_embedding = user_query_embedding.reshape(1, -1)

    if len(resort_embeddings.shape) == 1:
        resort_embeddings = resort_embeddings.reshape(1, -1)

    # Calculate cosine similarities
    similarities = cosine_similarity(user_query_embedding, resort_embeddings)
    sorted_indices = np.argsort(similarities[0])[::-1][:top_n]
    
    # Return the top N matching resorts
    top_resorts = [resorts[i] for i in sorted_indices]
    print(f"Top matching resorts: {top_resorts}")
    return top_resorts

# Main code execution
user_query = "Best ski resorts near Amherst"
location = extract_location(user_query)

latitude, longitude = get_lat_lng_from_location(location)

if latitude and longitude:
    print(f"Location: {location} (Lat: {latitude}, Lng: {longitude})")
    ski_resorts = get_ski_resorts(latitude, longitude)
    
    if not ski_resorts:
        print("No ski resorts found near the location.")
    else:
        resort_embeddings = create_resort_embeddings(ski_resorts)
        
        if resort_embeddings.shape[0] == 0:
            print("No valid resort embeddings generated.")
        else:
            top_resorts = get_top_matches(user_query, resort_embeddings, ski_resorts, top_n=10)
            
            if top_resorts:
                for resort in top_resorts:
                    print(f"🏔️ {resort['name']} - {resort['address']} (⭐ {resort['rating']})")
            else:
                print("No matching resorts found.")
else:
    print("Failed to retrieve location coordinates.")
# Out:
# Location: Amherst (Lat: 42.3732216, Lng: -72.5198537)
# Found 8 results for keyword: ski resort
# Checking ChIJfScJ_0DQ4IkRVgkP73FIwF8 - Name: berkshire east mountain resort, Types: ['lodging', 'point_of_interest', 'establishment'], Summary:
# Checking ChIJsVuPbs1q54kRN8WNTwdQBvo - Name: otis ridge, Types: ['tourist_attraction', 'point_of_interest', 'establishment'], Summary:
# ❌ Rejected: otis ridge - Doesn't match criteria
# Checking ChIJb-aCXFg64YkRNFSWIi5TZPY - Name: northfield mountain ski center, Types: ['campground', 'park', 'lodging', 'point_of_interest', 'establishment'], Summary:
# Checking ChIJe1XbO1pH54kRqsINPBXbnsE - Name: canterbury farm, Types: ['lodging', 'point_of_interest', 'establishment'], Summary: country-style b&b offering 3 cozy rooms & a rustic cabin, plus hot breakfast & outdoor activities.
# ❌ Rejected: canterbury farm - Doesn't match criteria
# ...

# %%
import requests
from dotenv import load_dotenv
import os
import time
import spacy
from sentence_transformers import SentenceTransformer
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from geopy.distance import geodesic
import math

# Load environment variables
load_dotenv()
API_KEY = "AIzaSyA6N-afJlUegG7uhVeUyAlusbLK912IH70"

# Initialize sentence transformer and spaCy models
model = SentenceTransformer('paraphrase-distilroberta-base-v1')
nlp = spacy.load("en_core_web_trf")

def get_lat_lng_from_location(location):
    geocode_url = "https://maps.googleapis.com/maps/api/geocode/json"
    params = {"address": location, "key": API_KEY}
    
    response = requests.get(geocode_url, params=params)
    data = response.json()
    
    if "results" in data and data["results"]:
        lat = data["results"][0]["geometry"]["location"]["lat"]
        lng = data["results"][0]["geometry"]["location"]["lng"]
        return lat, lng
    return None, None

def is_valid_ski_resort(place_id):
    details_url = "https://maps.googleapis.com/maps/api/place/details/json"
    params = {"place_id": place_id, "key": API_KEY, "fields": "name,types,editorial_summary,reviews"}

    response = requests.get(details_url, params=params)
    data = response.json()

    if "result" not in data:
        return False

    result = data["result"]
    name = result.get("name", "").lower()
    summary = result.get("editorial_summary", {}).get("overview", "").lower()
    types = result.get("types", [])
    reviews = result.get("reviews", [])

    ski_types = {"ski_resort", "ski_area", "ski_lift", "point_of_interest", "establishment", "mountain", "snow_resort", "snow_park"}
    excluded_types = {"park", "nature_reserve", "sledding_hill", "game_refuge", "tourist_attraction", "store", "shop", "farm", "forest", "recreation_area", "campground"}
    ski_keywords = {"ski resort", "ski area", "snowboard", "alpine", "downhill", "powder", "lift", "slope", "snow park", "snow resort", "skiing", "snowboarding", "winter sports", "ski lift", "mountain"}

    review_text = " ".join([review.get("text", "").lower() for review in reviews])
    has_ski_reviews = any(kw in review_text for kw in ski_keywords)

    if (
        (any(t in ski_types for t in types)) and
        not (any(t in excluded_types for t in types)) and
        (any(kw in name or kw in summary for kw in ski_keywords) or has_ski_reviews)
    ):
        return True

    return False

def create_grid(lat, lng, radius_km=200, grid_size=50):
    """
    Create a grid of latitude and longitude points within the radius.
    `grid_size` controls how fine the grid is.
    """
    km_to_degree = 1 / 111.32  # Approximate conversion from km to degrees
    lat_diff = radius_km * km_to_degree
    lng_diff = radius_km * km_to_degree / math.cos(math.radians(lat))

    # Create the grid points within the specified radius
    grid_points = []
    for i in range(-grid_size, grid_size + 1):
        for j in range(-grid_size, grid_size + 1):
            new_lat = lat + (i * lat_diff)
            new_lng = lng + (j * lng_diff)
            grid_points.append((new_lat, new_lng))
    
    return grid_points

def get_ski_resorts_with_grid(lat, lng, radius_km=200):
    """
    Fetch ski resorts by searching multiple grid points within the given radius.
    """
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    all_resorts = []
    seen_resorts = set()

    # Get grid points for the search area
    grid_points = create_grid(lat, lng, radius_km)

    keywords = ["ski resort", "ski area", "snowboarding", "alpine skiing", "ski mountain", "snow resort", "snow park", "winter sports"]

    for center_lat, center_lng in grid_points:
        for keyword in keywords:
            next_page_token = None
            while True:
                params = {
                    "location": f"{center_lat},{center_lng}",
                    "radius": 50000,  # Max 50km radius per API request
                    "keyword": keyword,
                    "key": API_KEY
                }

                if next_page_token:
                    params["pagetoken"] = next_page_token

                response = requests.get(url, params=params)
                data = response.json()

                if data.get("status") != "OK":
                    break

                if "results" in data:
                    for place in data["results"]:
                        place_id = place.get("place_id")
                        if place_id in seen_resorts:
                            continue

                        if is_valid_ski_resort(place_id):
                            resort = {
                                "name": place.get("name"),
                                "address": place.get("vicinity"),
                                "rating": place.get("rating", "N/A"),
                                "lat": place["geometry"]["location"]["lat"],
                                "lng": place["geometry"]["location"]["lng"]
                            }
                            all_resorts.append(resort)
                            seen_resorts.add(place_id)

                next_page_token = data.get("next_page_token")
                if not next_page_token:
                    break

                time.sleep(2)  # Allow time before requesting the next page

    # Apply the distance filtering here after getting all resorts
    all_resorts = filter_by_distance(all_resorts, lat, lng, max_distance_km=radius_km)

    return all_resorts

def extract_location(query):
    doc = nlp(query)
    locations = [ent.text for ent in doc.ents if ent.label_ in ["GPE", "LOC"]]
    return locations[0] if locations else None

def create_resort_embeddings(resorts):
    embeddings = []
    for resort in resorts:
        text = resort['name'] + " " + resort['address']
        embedding = model.encode(text)
        embeddings.append(embedding)
    return np.array(embeddings)

def get_top_matches(query, resort_embeddings, resorts, top_n=5):
    user_query_embedding = model.encode(query).reshape(1, -1)
    similarities = cosine_similarity(user_query_embedding, resort_embeddings)
    similarities = similarities[0]

    resorts_with_scores = list(zip(resorts, similarities))
    top_resorts = sorted(
        resorts_with_scores,
        key=lambda x: (x[1], x[0].get("rating", 0)),
        reverse=True
    )[:top_n]

    top_resorts = [resort for resort, _ in top_resorts]

    return top_resorts

def filter_by_distance(resorts, lat, lng, max_distance_km=200):
    filtered_resorts = []
    user_location = (lat, lng)

    for resort in resorts:
        resort_location = (resort["lat"], resort["lng"])
        distance = geodesic(user_location, resort_location).km
        if distance <= max_distance_km:  
            resort["distance"] = distance
            filtered_resorts.append(resort)

    return filtered_resorts

def filter_invalid_resorts(resorts):
    return [resort for resort in resorts if resort["rating"] > 0]

def sort_resorts(resorts):
    return sorted(resorts, key=lambda x: (-x['rating'], x['distance']))

user_query = "Best ski resorts near Amherst"
location = extract_location(user_query)

if location:
    latitude, longitude = get_lat_lng_from_location(location)
    if latitude and longitude:
        ski_resorts = get_ski_resorts_with_grid(latitude, longitude)
        
        if ski_resorts:
            resort_embeddings = create_resort_embeddings(ski_resorts)
            top_resorts = get_top_matches(user_query, resort_embeddings, ski_resorts, top_n=50)
            valid_resorts = filter_invalid_resorts(top_resorts)
            sorted_resorts = sort_resorts(valid_resorts)
            
            for resort in sorted_resorts:
                print(f"🏔️ {resort['name']} - {resort['address']} (⭐ {resort['rating']}, 📍 {resort['distance']} km)")
# Out:
# /Users/saimnaushad/.pyenv/versions/3.8.10/lib/python3.8/site-packages/huggingface_hub/file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ...

# %%
import requests
from dotenv import load_dotenv
import os
import time
import spacy
from sentence_transformers import SentenceTransformer
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from geopy.distance import geodesic

# Load API key
load_dotenv()
API_KEY = "AIzaSyA6N-afJlUegG7uhVeUyAlusbLK912IH70"

# Load NLP models
model = SentenceTransformer('paraphrase-distilroberta-base-v1')
nlp = spacy.load("en_core_web_trf")

### ---- (1) LOCATION HELPERS ---- ###
def get_lat_lng_from_location(location):
    """Fetch latitude and longitude for a given location using Google Geocode API."""
    url = "https://maps.googleapis.com/maps/api/geocode/json"
    params = {"address": location, "key": API_KEY}
    response = requests.get(url, params=params).json()
    
    if response.get("results"):
        lat = response["results"][0]["geometry"]["location"]["lat"]
        lng = response["results"][0]["geometry"]["location"]["lng"]
        return lat, lng
    return None, None

def extract_location(query):
    """Extract geographic location from a user query using NLP."""
    doc = nlp(query)
    locations = [ent.text for ent in doc.ents if ent.label_ in ["GPE", "LOC"]]
    return locations[0] if locations else None

### ---- (2) FETCH SKI RESORTS ---- ###
def fetch_ski_resorts_for_point(lat, lng):
    """Fetch ski resorts at a specific grid point (50 km radius per request)."""
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    results = []
    seen_resorts = set()

    next_page_token = None
    while True:
        params = {
            "location": f"{lat},{lng}",
            "radius": 50000,  # Max radius per request (50 km)
            "keyword": "ski resort|mountain",
            "type": "establishment",
            "key": API_KEY
        }
        if next_page_token:
            params["pagetoken"] = next_page_token

        response = requests.get(url, params=params).json()
        if response.get("status") != "OK":
            break

        for place in response.get("results", []):
            place_id = place.get("place_id")
            name = place.get("name", "").lower()

            # **Filter out ski shops, clubs, and non-resorts**
            if place_id in seen_resorts or any(term in name for term in ["shop", "club", "sledding", "touring", "tubing", "hill", "lodge", "center", "parking"]):
                continue

            resort = {
                "name": place.get("name"),
                "address": place.get("vicinity"),
                "rating": place.get("rating", 0),
                "lat": place["geometry"]["location"]["lat"],
                "lng": place["geometry"]["location"]["lng"]
            }
            results.append(resort)
            seen_resorts.add(place_id)

        next_page_token = response.get("next_page_token")
        if not next_page_token:
            break

        time.sleep(1)  # Reduce API rate-limit issues

    return results

def get_ski_resorts_grid_search(center_lat, center_lng, search_radius=100):
    """Perform a grid search to cover the full 200 km radius area."""
    step_distance = 50  # Step in km (matches Places API limit)
    lat_step = step_distance / 110.574  # Approx degrees per km
    lng_step = step_distance / (111.320 * abs(np.cos(np.radians(center_lat))))  

    ski_resorts = []
    for d_lat in [-1, 0, 1]:  # North, center, South
        for d_lng in [-1, 0, 1]:  # West, center, East
            lat = center_lat + d_lat * lat_step
            lng = center_lng + d_lng * lng_step
            ski_resorts.extend(fetch_ski_resorts_for_point(lat, lng))

    return ski_resorts

### ---- (3) FILTERING & RANKING ---- ###
def filter_by_distance(resorts, lat, lng, max_distance_km=100):
    """Filter resorts to ensure they are within 200 km of user location."""
    return [
        {**resort, "distance": geodesic((lat, lng), (resort["lat"], resort["lng"])).km}
        for resort in resorts if geodesic((lat, lng), (resort["lat"], resort["lng"])).km <= max_distance_km
    ]

def create_resort_embeddings(resorts):
    """Generate text embeddings for resorts."""
    return np.array([model.encode(resort["name"] + " " + resort["address"]) for resort in resorts])

def get_top_matches(query, resort_embeddings, resorts, top_n=10):
    """Find top N matches based on cosine similarity."""
    user_query_embedding = model.encode(query).reshape(1, -1)
    similarities = cosine_similarity(user_query_embedding, resort_embeddings)[0]
    sorted_resorts = sorted(zip(resorts, similarities), key=lambda x: -x[1])[:top_n]
    return [resort for resort, _ in sorted_resorts]

def remove_duplicates(resorts):
    """Remove duplicate resorts based on name and address."""
    unique_resorts = {}
    for resort in resorts:
        key = (resort["name"].lower(), resort["address"].lower())  # Unique identifier
        if key not in unique_resorts:
            unique_resorts[key] = resort
    return list(unique_resorts.values())

def remove_invalid_resorts(resorts):
    """Remove resorts with zero or invalid ratings."""
    return [resort for resort in resorts if resort['rating'] > 0]

def sort_resorts(resorts):
    """Sort resorts by rating (desc) and then by distance (asc)."""
    return sorted(resorts, key=lambda x: (-x["rating"], x["distance"]))

### ---- (4) MAIN EXECUTION ---- ###
def find_best_ski_resorts(user_query):
    """Main function to find ski resorts based on user query."""
    location = extract_location(user_query)
    if not location:
        return

    latitude, longitude = get_lat_lng_from_location(location)
    if not latitude or not longitude:
        return

    ski_resorts = get_ski_resorts_grid_search(latitude, longitude)

    # **Filter, Remove Duplicates & Rank**
    ski_resorts = filter_by_distance(ski_resorts, latitude, longitude)
    ski_resorts = remove_duplicates(ski_resorts)  # **NEW STEP**
    ski_resorts = remove_invalid_resorts(ski_resorts)  # **NEW STEP**
    
    if not ski_resorts:
        return

    resort_embeddings = create_resort_embeddings(ski_resorts)
    top_resorts = get_top_matches(user_query, resort_embeddings, ski_resorts, top_n=50)
    sorted_resorts = sort_resorts(top_resorts)

    # **Only print ski resorts**
    for resort in sorted_resorts:
        print(f"🏔️ {resort['name']} - {resort['address']} (⭐ {resort['rating']}, 📍 {round(resort['distance'], 2)} km)")
    print(len(sorted_resorts))

# **Run Search**
user_query = "ski resorts near Amherst"
find_best_ski_resorts(user_query)
# Out:
# /Users/saimnaushad/.pyenv/versions/3.8.10/lib/python3.8/site-packages/huggingface_hub/file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ...

# %%
import requests
from dotenv import load_dotenv
import os
import time
import spacy
from sentence_transformers import SentenceTransformer
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from geopy.distance import geodesic
from functools import lru_cache
from concurrent.futures import ThreadPoolExecutor

# Load API key
load_dotenv()
API_KEY = "AIzaSyA6N-afJlUegG7uhVeUyAlusbLK912IH70"

# Load NLP models
model = SentenceTransformer('paraphrase-distilroberta-base-v1')
nlp = spacy.load("en_core_web_trf")

### ---- (1) LOCATION HELPERS ---- ###
@lru_cache(maxsize=100)
def get_lat_lng_from_location(location):
    """Fetch latitude and longitude for a given location using Google Geocode API."""
    url = "https://maps.googleapis.com/maps/api/geocode/json"
    params = {"address": location, "key": API_KEY}
    response = requests.get(url, params=params).json()
    
    if response.get("results"):
        lat = response["results"][0]["geometry"]["location"]["lat"]
        lng = response["results"][0]["geometry"]["location"]["lng"]
        return lat, lng
    return None, None

def extract_location(query):
    """Extract geographic location from a user query using NLP."""
    doc = nlp(query)
    locations = [ent.text for ent in doc.ents if ent.label_ in ["GPE", "LOC"]]
    return locations[0] if locations else None

### ---- (2) FETCH SKI RESORTS ---- ###
def fetch_ski_resorts_for_point(lat, lng):
    """Fetch ski resorts at a specific grid point (50 km radius per request)."""
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    results = []
    seen_resorts = set()

    next_page_token = None
    while True:
        params = {
            "location": f"{lat},{lng}",
            "radius": 50000,  # Max radius per request (50 km)
            "keyword": "ski resort|mountain",
            "type": "establishment",
            "key": API_KEY
        }
        if next_page_token:
            params["pagetoken"] = next_page_token

        response = requests.get(url, params=params)

        if response.status_code != 200:
            print(f"Error fetching data: {response.status_code}")
            break

        data = response.json()  # Use the json method to convert response content to a dictionary
        
        if data.get("status") != "OK":
            print(f"Error in response: {data.get('status')}")
            break

        for place in data.get("results", []):
            place_id = place.get("place_id")
            name = place.get("name", "").lower()

            # **Filter out ski shops, clubs, and non-resorts**
            if place_id in seen_resorts or any(term in name for term in ["shop", "club", "sledding", "touring", "tubing", "hill", "lodge", "center", "parking"]):
                continue

            resort = {
                "name": place.get("name"),
                "address": place.get("vicinity"),
                "rating": place.get("rating", 0),
                "lat": place["geometry"]["location"]["lat"],
                "lng": place["geometry"]["location"]["lng"]
            }
            results.append(resort)
            seen_resorts.add(place_id)

        next_page_token = data.get("next_page_token")
        if not next_page_token:
            break

        time.sleep(1)  # Reduce API rate-limit issues

    return results


def handle_rate_limit(response):
    """Handle rate limit by sleeping if necessary."""
    remaining = int(response.headers.get('X-RateLimit-Remaining', 1))
    if remaining <= 1:
        reset_time = int(response.headers.get('X-RateLimit-Reset', time.time() + 60))
        wait_time = max(0, reset_time - time.time())
        time.sleep(wait_time)

def get_ski_resorts_grid_search(center_lat, center_lng, search_radius=100):
    """Perform a grid search to cover the full 200 km radius area."""
    step_distance = 50  # Step in km (matches Places API limit)
    lat_step = step_distance / 110.574  # Approx degrees per km
    lng_step = step_distance / (111.320 * abs(np.cos(np.radians(center_lat))))  

    ski_resorts = []
    with ThreadPoolExecutor(max_workers=5) as executor:
        lat_lng_points = [(center_lat + d_lat * lat_step, center_lng + d_lng * lng_step) for d_lat in [-1, 0, 1] for d_lng in [-1, 0, 1]]
        ski_resorts = list(executor.map(lambda point: fetch_ski_resorts_for_point(*point), lat_lng_points))
    return [resort for sublist in ski_resorts for resort in sublist]

### ---- (3) FILTERING & RANKING ---- ###
def filter_by_distance(resorts, lat, lng, max_distance_km=100):
    """Filter resorts to ensure they are within 200 km of user location."""
    return [
        {**resort, "distance": geodesic((lat, lng), (resort["lat"], resort["lng"])).km}
        for resort in resorts if geodesic((lat, lng), (resort["lat"], resort["lng"])).km <= max_distance_km
    ]

def create_resort_embeddings(resorts):
    """Generate text embeddings for resorts."""
    return np.array([model.encode(resort["name"] + " " + resort["address"]) for resort in resorts])

def get_top_matches(query, resort_embeddings, resorts, top_n=10):
    """Find top N matches based on cosine similarity."""
    user_query_embedding = model.encode(query).reshape(1, -1)
    similarities = cosine_similarity(user_query_embedding, resort_embeddings)[0]
    sorted_resorts = sorted(zip(resorts, similarities), key=lambda x: -x[1])[:top_n]
    return [resort for resort, _ in sorted_resorts]

def remove_duplicates(resorts):
    """Remove duplicate resorts based on name and address."""
    unique_resorts = {}
    for resort in resorts:
        key = (resort["name"].lower(), resort["address"].lower())  # Unique identifier
        if key not in unique_resorts:
            unique_resorts[key] = resort
    return list(unique_resorts.values())

def remove_invalid_resorts(resorts):
    """Remove resorts with zero or invalid ratings."""
    return [resort for resort in resorts if resort['rating'] > 0]

def sort_resorts(resorts):
    """Sort resorts by rating (desc) and then by distance (asc)."""
    return sorted(resorts, key=lambda x: (-x["rating"], x["distance"]))

### ---- (4) MAIN EXECUTION ---- ###
def find_best_ski_resorts(user_query):
    """Main function to find ski resorts based on user query."""
    location = extract_location(user_query)
    if not location:
        return

    latitude, longitude = get_lat_lng_from_location(location)
    if not latitude or not longitude:
        return

    ski_resorts = get_ski_resorts_grid_search(latitude, longitude)

    # **Filter, Remove Duplicates & Rank**
    ski_resorts = filter_by_distance(ski_resorts, latitude, longitude)
    ski_resorts = remove_duplicates(ski_resorts)  # **NEW STEP**
    ski_resorts = remove_invalid_resorts(ski_resorts)  # **NEW STEP**
    
    if not ski_resorts:
        return

    resort_embeddings = create_resort_embeddings(ski_resorts)
    top_resorts = get_top_matches(user_query, resort_embeddings, ski_resorts, top_n=50)
    sorted_resorts = sort_resorts(top_resorts)

    # **Return ski resorts instead of printing**
    return sorted_resorts

# **Run Search**
user_query = "ski resorts near Amherst"
sorted_resorts = find_best_ski_resorts(user_query)

# Optionally: Output the results
if sorted_resorts:
    for resort in sorted_resorts:
        print(f"🏔️ {resort['name']} - {resort['address']} (⭐ {resort['rating']}, 📍 {round(resort['distance'], 2)} km)")
    print(len(sorted_resorts))
# Out:
# /Users/saimnaushad/.pyenv/versions/3.8.10/lib/python3.8/site-packages/huggingface_hub/file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ...

# %%
pip install geopy
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...
#      |████████████████████████████████| 125 kB 3.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 40 kB 12.3 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.1.1; however, version 25.0.1 is available.
# You should consider upgrading via the '/Users/saimnaushad/.pyenv/versions/3.8.10/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install spacy-transformers torch torchvision torchaudio transformers
# Out:
# ...
# WARNING: You are using pip version 21.1.1; however, version 25.0.1 is available.
# You should consider upgrading via the '/Users/saimnaushad/.pyenv/versions/3.8.10/bin/python3.8 -m pip install --upgrade pip' command.

# %%
# !python -m spacy download en_core_web_trf
# Out:
# /Users/saimnaushad/.pyenv/versions/3.8.10/lib/python3.8/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# ...
#      |████████████████████████████████| 457.4 MB 9.4 MB/s eta 0:00:014    |█████▊                          | 81.8 MB 9.7 MB/s eta 0:00:39
# ...
# WARNING: You are using pip version 21.1.1; however, version 25.0.1 is available.
# You should consider upgrading via the '/Users/saimnaushad/.pyenv/versions/3.8.10/bin/python -m pip install --upgrade pip' command.
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')

# %%
pip install -U spacy
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...
#   Using cached spacy-3.8.2.tar.gz (1.3 MB)
#   Installing build dependencies ... error
#   ERROR: Command errored out with exit status 1:
# ...

# %%
# !python -c "import spacy; print(spacy.__version__)"
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 3.7.5
